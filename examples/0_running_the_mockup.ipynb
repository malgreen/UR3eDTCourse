# %% [markdown]
# # Running the UR3e Mockup
#
# This notebook provides instructions on how to run and interact with the UR3e Mockup. **Make sure to have the environment set up as described in the [Environment Setup](0_environment_setup.ipynb) notebook before proceeding.**

# %% [markdown]
# ## Starting the mockup
#
# The UR3e mockup is located in the `ur3e_mockup` folder. To start the mockup, open a terminal in the **root folder** of the project and run the following command:
#
# ```bash
# python -m startup.start_ur3e_mockup
# ```
# It might take a few seconds/minutes for the mockup to start the first time, as it needs to initialize all the components.
#
# <!-- highlighted text -->
# > Note: If you encounter any issues related to RabbitMQ connection, ensure that the RabbitMQ server is running and accessible with the credentials specified in the `startup/startup.conf` file. If you created the RabbitMQ server with different credentials, please update the `username` and `password` fields in the configuration file (`startup/startup.conf`) accordingly.
#
# > Note: If the mockup is not recognized as a valid executable, you might need to make it executable. You can do this by running the following command in the terminal:
#
# ```bash
# chmod +x ur3e_mockup/ur3e_mockup_*
# ```
# ---
#
# When started successfully, you should see an output like this:
#
# ```bash
# 2026-01-09 15:02:48,153 - __main__ - INFO - Starting UR3e Robot Arm Mockup
# 2026-01-09 15:02:48,153 - __main__ - INFO - Loading config from external file: /Users/au691667/Documents/ur3e_mockup_STUDENT/startup/startup.conf
# 2026-01-09 15:02:48,164 - ur3e_mockup.robot_arm_mockup - INFO - RobotArmMockup created successfully.
# 2026-01-09 15:02:48,164 - __main__ - INFO - Setting up RobotArmMockup
# 2026-01-09 15:02:48,170 - pika.adapters.utils.connection_workflow - INFO - Pika version 1.3.2 connecting to ('::1', 5672, 0, 0)
# 2026-01-09 15:02:48,171 - pika.adapters.utils.io_services_utils - INFO - Socket connected: <socket.socket fd=9, family=30, type=1, proto=6, laddr=('::1', 52956, 0, 0), raddr=('::1', 5672, 0, 0)>
# 2026-01-09 15:02:48,171 - pika.adapters.utils.connection_workflow - INFO - Streaming transport linked up: (<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0x12390c830>, _StreamingProtocolShim: <SelectConnection PROTOCOL transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0x12390c830> params=<ConnectionParameters host=localhost port=5672 virtual_host=/ ssl=False>>).
# 2026-01-09 15:02:48,178 - pika.adapters.utils.connection_workflow - INFO - AMQPConnector - reporting success: <SelectConnection OPEN transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0x12390c830> params=<ConnectionParameters host=localhost port=5672 virtual_host=/ ssl=False>>
# 2026-01-09 15:02:48,178 - pika.adapters.utils.connection_workflow - INFO - AMQPConnectionWorkflow - reporting success: <SelectConnection OPEN transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0x12390c830> params=<ConnectionParameters host=localhost port=5672 virtual_host=/ ssl=False>>
# 2026-01-09 15:02:48,178 - pika.adapters.blocking_connection - INFO - Connection workflow succeeded: <SelectConnection OPEN transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0x12390c830> params=<ConnectionParameters host=localhost port=5672 virtual_host=/ ssl=False>>
# 2026-01-09 15:02:48,178 - pika.adapters.blocking_connection - INFO - Created channel=1
# 2026-01-09 15:02:48,182 - pika.adapters.utils.connection_workflow - INFO - Pika version 1.3.2 connecting to ('::1', 5672, 0, 0)
# 2026-01-09 15:02:48,182 - pika.adapters.utils.io_services_utils - INFO - Socket connected: <socket.socket fd=13, family=30, type=1, proto=6, laddr=('::1', 52959, 0, 0), raddr=('::1', 5672, 0, 0)>
# 2026-01-09 15:02:48,182 - pika.adapters.utils.connection_workflow - INFO - Streaming transport linked up: (<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0x123901f90>, _StreamingProtocolShim: <SelectConnection PROTOCOL transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0x123901f90> params=<ConnectionParameters host=localhost port=5672 virtual_host=/ ssl=False>>).
# 2026-01-09 15:02:48,187 - pika.adapters.utils.connection_workflow - INFO - AMQPConnector - reporting success: <SelectConnection OPEN transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0x123901f90> params=<ConnectionParameters host=localhost port=5672 virtual_host=/ ssl=False>>
# 2026-01-09 15:02:48,187 - pika.adapters.utils.connection_workflow - INFO - AMQPConnectionWorkflow - reporting success: <SelectConnection OPEN transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0x123901f90> params=<ConnectionParameters host=localhost port=5672 virtual_host=/ ssl=False>>
# 2026-01-09 15:02:48,187 - pika.adapters.blocking_connection - INFO - Connection workflow succeeded: <SelectConnection OPEN transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0x123901f90> params=<ConnectionParameters host=localhost port=5672 virtual_host=/ ssl=False>>
# 2026-01-09 15:02:48,187 - pika.adapters.blocking_connection - INFO - Created channel=1
# 2026-01-09 15:02:48,189 - ur3e_mockup.robot_arm_mockup - INFO - RabbitMQ connections established
# 2026-01-09 15:02:48,194 - communication.rabbitmq - INFO - Bound robotarm.ctrl--> amq.gen-6q6zD9c8dm9SxmO8l1zugw
# 2026-01-09 15:02:48,194 - ur3e_mockup.robot_arm_mockup - INFO - Control message subscription established
# 2026-01-09 15:02:48,195 - __main__ - INFO - Starting RobotArmMockup control loop
# 2026-01-09 15:02:48,195 - ur3e_mockup.robot_arm_mockup - INFO - Starting RabbitMQ consumption
# ```

# %% [markdown]
# To shut it down, simply press `CTRL+C` in the terminal where the mockup is running.
